# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # MATPLOTLIB for Python Developers - Chap2
# Estudos e exercícios do livro

# %% [markdown]
# ## Line plots

# %%
plt.plot([1, 3, 2, 4])

# %%
x = range(6)
plt.plot(x,[xi**2 for xi in x])

# %%
x = np.arange(0.0,6,0.01)
plt.plot(x,[xi**2 for xi in x])

# %% [markdown]
# ## Multiline Plots

# %%
x = range(1,5)
plt.plot(x, [xi*1.5 for xi in x])
plt.plot(x, [xi*3.0 for xi in x])
plt.plot(x, [xi/3.0 for xi in x])

# %%
x = range(1,5)
plt.plot(x, [xi*1.5 for xi in x], x, [xi*3.0 for xi in x], x,
[xi/3.0 for xi in x])

# %% [markdown]
# ### obs: usar o metodo arange do NumPy facilita muito mais que usar simplismente a lista gerada pelo range()

# %%
x = np.arange(1,5)
plt.plot(x,x*1.5,x,x*3,x,x/3)

# %% [markdown]
# obs: np.arange(x) simula o range(), mas retorna uma array

# %% [markdown]
# ## Grid, axes and labels
#
# ### Grid

# %%
x = np.arange(1,5)
plt.plot(x,x*1.5,x,x*3,x,x/3)
plt.grid(True)

# %% [markdown]
# ### Axes (definindo os limites dos eixos)

# %%
x = np.arange(1,5)
plt.plot(x,x*1.5,x,x*3,x,x/3)
# o comando plt.axis() printa os limites atuais
plt.axis([0,5,-1,13]) # set os novos limites
# Out:
# [0, 5, -1, 13]

# %% [markdown]
# ### Labels

# %%
plt.plot([1,3,2,4])
plt.xlabel('This is X axis')
plt.ylabel('This is Y axis')
# Out:
# Text(0,0.5,'This is Y axis')

# %% [markdown]
# ## Titles and Legends

# %%
plt.plot([1,3,2,4])
plt.title('Simple plot')
# Out:
# Text(0.5,1,'Simple plot')

# %%
x = np.arange(1,5)
plt.plot(x,x*1.5, label='Normal')
plt.plot(x,x*3.0, label='Fast')
plt.plot(x,x/3.0, label='Slow')
plt.legend()

# %% [markdown]
# ## Saving plots to a file

# %%
plt.plot([1,2,3])
plt.savefig('plot123.png')

# %%
plt.style.use('seaborn-poster')

# %%
x = np.arange(0,100,0.01)

plt.plot(x,x/3 + x**2 + x**3 - 42*x**5, label = 'Equação 1')
plt.legend()
plt.title('Título do gráfico')
plt.xlabel('Tempo (dias)')
plt.ylabel('Sensor')
# Out:
# Text(0,0.5,'Sensor')
